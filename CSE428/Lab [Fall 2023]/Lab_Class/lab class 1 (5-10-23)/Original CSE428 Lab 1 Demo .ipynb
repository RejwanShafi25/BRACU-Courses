# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, transform, img_as_float

# %%
x = [1, 2, 4, 5, 7]
print(x)
# Out:
# [1, 2, 4, 5, 7]

# %%
x = x + 4
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-6f8bcaa613ef> in <cell line: 1>()
# ----> 1 x = x + 4
#       2 print(x)
#
# TypeError: can only concatenate list (not "int") to list

# %%
for i in range(len(x)):
  x[i] = x[i] + 4
print(x)
# Out:
# [5, 6, 8, 9, 11]

# %%
x = np.array([1, 2, 4, 5, 7])
print(x)
# Out:
# [1 2 4 5 7]

# %%
# x = x+4
print(x*4)
# Out:
# [ 4  8 16 20 28]

# %% [markdown]
# 2 3 4
#
# 5 6 7

# %%
# declare an array of 2 rows, 3 columns
x = np.array([[2,3,4],[5,6,14]])

# %%
print(x)
# Out:
# [[ 2  3  4]
#  [ 5  6 14]]

# %%
plt.imshow(x, cmap='gray')

# %%
x[1,:]
# Out:
# array([ 5,  6, 14])

# %%
x = np.array([1, 2, 4, 5, 7, 12, -55, 77, 10])

# %%
print(x[3])
# Out:
# 5

# %%
print(x[-5])
# Out:
# 7

# %%
x = np.array([[2,3,4],[5,6,7]])
print(x)
print(x[0][-1])
print(x[0,-1])
# Out:
# [[2 3 4]
#  [5 6 7]]
# 4
# 4

# %%
x = np.array([[[2,3,4],[5,6,7]],[[2,3,4],[5,6,7]]])
print(x)
# Out:
# [[[2 3 4]
#   [5 6 7]]
#
#  [[2 3 4]
#   [5 6 7]]]

# %% [markdown]
# x[start:end] = [x[start], x[start+1], ....., x[end-1]]

# %%
x = np.array([1, 2, 4, 5, 7, 8, 9, 12])
print(x[1:-1])
# Out:
# [2 4 5 7 8 9]

# %%
x[1:-1:3]
# Out:
# array([2, 7])

# %% [markdown]
# x[start:end:step] = x[start], x[start+step], x[start+2*step],.... x[end-1]

# %%
print(x[0:5])
# Out:
# [1 2 4 5 7]

# %%
print(x[1:4:2])
# Out:
# [2 5]

# %%
print(x[::1])
# Out:
# [ 1  2  4  5  7  8  9 12]

# %%
print(x[::-1])
# Out:
# [12  9  8  7  5  4  2  1]

# %%
print(x[::-2])
# Out:
# [12  8  5  2]

# %%
x = np.array([[2,3,4],[5,6,7]])
print(x)
# Out:
# [[2 3 4]
#  [5 6 7]]

# %%
# x[20:35][100:120]

# %%
print(x[:,::2])
# Out:
# [[2 4]
#  [5 7]]

# %% [markdown]
# `x[start:end]`
#
# `x[start:end:step]`
#
# `x[::]`
#
# start is not specified, 0
#
# end is not specified, len(x)
#
# step is not specified, 1

# %%
# boolean indexing

x = np.array([2, 1, -5, -4, 4, 5])

# %%
x[x>0]
# Out:
# array([2, 1, 4, 5])

# %%
x*(x>0)
# Out:
# array([2, 1, 0, 0, 4, 5])

# %%
index = [False, False, True, True, False, False]

# %%
x[index]
# Out:
# array([-5, -4])

# %%
index = x < 0

# %%
index
# Out:
# array([False, False,  True,  True, False, False])

# %%
x[index]
# Out:
# array([-5, -4])

# %%
x[ x < 0 ]
# Out:
# array([-5, -4])

# %% [markdown]
# ## Slicing Summary
#
# `x[start:end:step] = [x[start], x[start+step], x[start+2*step], ... x[end-1]]`
#
# If `start` not specified, assumes `0`
#
# If `end` not specified, assumes `len(x)`
#
# If `step` not specified, assumes `1`
#
# **Boolean indexing**: `x[ind]` where `ind` is an array of `True` and `False` with the same size as `x`

# %%
x = np.array([4, 1, -1, 2, 4, 5])
print(x[1:4]) # [1, -1, 2]
print(x[1:]) # [1, -1, 2, 4, 5]
print(x[:4]) # []
print(x[:]) # []
print(x[2::2]) # []
print(x[:6:2]) # []
# Out:
# [ 1 -1  2]
# [ 1 -1  2  4  5]
# [ 4  1 -1  2]
# [ 4  1 -1  2  4  5]
# [-1  4]
# [ 4 -1  4]

# %% [markdown]
# # Image as NumPy array

# %%
x = np.random.rand(4, 5)
print(x)
print("shape -", x.shape)
# Out:
# [[0.37190989 0.96620169 0.63087056 0.7877604  0.68396464]
#  [0.36543231 0.11117777 0.12829306 0.46444084 0.76354829]
#  [0.55128564 0.18460464 0.07983449 0.33323462 0.49416131]
#  [0.05341484 0.42050419 0.15231333 0.21657821 0.03089891]]
# shape - (4, 5)

# %%
plt.imshow(x, cmap='gray',)
# plt.axis("off")

# %%
x.shape
# Out:
# (4, 5)

# %%
#height, width = x.shape[:2]
height = x.shape[0]
width = x.shape[1]
print("Height =", height)
print("Width =", width)
# Out:
# Height = 4
# Width = 5

# %%
x = np.random.rand(4, 5, 3)
height, width, nchannels = x.shape
print("Height =", height)
print("Width =", width)
print("Number of channels =", nchannels)
# Out:
# Height = 4
# Width = 5
# Number of channels = 3

# %%
# print(x)

# %%
print("Red Channel")
print(x[:, :, 0])

print("Green Channel")
print(x[:, :, 1])

print("Blue Channel")
print(x[:, :, 2])
# Out:
# Red Channel
# [[0.056152   0.7494348  0.27919468 0.07310685 0.64496846]
#  [0.87212354 0.20216193 0.72250632 0.15721342 0.22137795]
#  [0.29386306 0.74332893 0.00939905 0.50221416 0.55503093]
#  [0.50013041 0.84994643 0.71943169 0.98973253 0.79976297]]
# Green Channel
# [[0.77040925 0.56548111 0.77020351 0.99232709 0.22428196]
#  [0.05817209 0.757842   0.61248114 0.92877096 0.97401492]
#  [0.4533408  0.32876294 0.22223827 0.47168032 0.59246203]
#  [0.38403284 0.08396728 0.05574122 0.53570014 0.84004902]]
# Blue Channel
# [[0.49308301 0.40931236 0.54450122 0.57418848 0.03486624]
#  [0.32406669 0.7187591  0.979907   0.17190012 0.66867514]
#  [0.91193009 0.14356852 0.79632582 0.09163281 0.56425742]
#  [0.14530278 0.84544181 0.58967109 0.45695973 0.65392349]]

# %%
io.imshow(x)
plt.axis("off")

# %%
plt.figure(figsize=(4, 4))
x_cropped = x[-3:,-3:,:]
io.imshow(x_cropped)
plt.axis("off")
# Out:
# (-0.5, 2.5, 2.5, -0.5)

# %% [markdown]
# # Real Digital Image

# %%
I = io.imread("cat_1.jpg")
height, width = I.shape[:2]
print("Height =", height)
print("Width =", width)
# Out:
# Height = 2657
# Width = 1771

# %%
plt.figure(figsize=(5, 2))
io.imshow(I)
#plt.axis("off")

# %%
# print(I)

# %%
x = I[0, 0]
y = I[-1, 0]
print(x)
print(y)
# Out:
# [161 163 175]
# [22 21 19]

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Problem with **uint8**

# %%
x + y
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in ubyte_scalars
#   """Entry point for launching an IPython kernel.
# 113

# %%
# Bad way of normalization
# I = I/255

# Good way
I = img_as_float(I)
I = img_as_float(I)

# %%
plt.figure(figsize=(3, 3))
io.imshow(I)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %% [markdown]
# ## Example 2

# %%
I = io.imread("cat_1.jpg")

# %%
I.shape
# Out:
# (2657, 1771, 3)

# %%
height, width, nchannels = I.shape
print("Height =", height)
print("Width =", width)
print("Number of channels =", nchannels)
# Out:
# Height = 2657
# Width = 1771
# Number of channels = 3

# %%
io.imshow(I)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Red channel
axes[0].imshow(I[:, :, 0], cmap="gray")
axes[0].axis("off")
axes[0].set_title("Red")

# Green channel
axes[1].imshow(I[:, :, 1], cmap="gray")
axes[1].axis("off")
axes[1].set_title("Green")

# Blue channel
axes[2].imshow(I[:, :, 2], cmap="gray")
axes[2].axis("off")
axes[2].set_title("Blue")
# Out:
# Text(0.5, 1.0, 'Blue')

# %%
12//2
# Out:
# 6

# %%
# Only the left half of the image
I_cropped = I[:, :width//2, :]
io.imshow(I_cropped)
plt.axis("off")
# Out:
# (-0.5, 884.5, 2656.5, -0.5)

# %%
# Only the  bottom half of the image
I_cropped = I[height//2:, :, :]
io.imshow(I_cropped)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 1328.5, -0.5)

# %%
# flip along width (with respect to y axis)
# I_flipped = I[:, ::-1, :]
I_flipped = I[:, :, ::-1]
io.imshow(I_flipped)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %%
# flip along height (with respect to x axis)
I_flipped = I[::-1, :, :]
io.imshow(I_flipped)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %%
# Rotate 180 degree
I_rotated = I[::-1, ::-1, :]
io.imshow(I_rotated)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %%
# Downsample
I_rotated = I[::40*2, ::40*2, :]
io.imshow(I_rotated)
plt.axis("off")
# Out:
# (-0.5, 22.5, 33.5, -0.5)

# %% [markdown]
# # Example 3

# %%
I = io.imread("/content/BracU_Logo.png")

# %%
io.imshow(I)

# %%
I.shape
# Out:
# (275, 300, 3)

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# Red channel
axes[0].imshow(I[:, :, 0], cmap="gray")
axes[0].axis("off")
axes[0].set_title("Red")

# Green channel
axes[1].imshow(I[:, :, 1], cmap="gray")
axes[1].axis("off")
axes[1].set_title("Green")

# Blue channel
axes[2].imshow(I[:, :, 2], cmap="gray")
axes[2].axis("off")
axes[2].set_title("Blue")

# Alpha channel
axes[3].imshow(I[:, :, 3], cmap="gray")
axes[3].axis("off")
axes[3].set_title("Alpha")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-153-610c1a329dae> in <cell line: 19>()
#      17
#      18 # Alpha channel
# ---> 19 axes[3].imshow(I[:, :, 3], cmap="gray")
#      20 axes[3].axis("off")
#      21 axes[3].set_title("Alpha")
#
# IndexError: index 3 is out of bounds for axis 2 with size 3
