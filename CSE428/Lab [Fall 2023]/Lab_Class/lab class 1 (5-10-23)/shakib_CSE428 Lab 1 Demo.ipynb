# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, transform, img_as_float

# %%
x = [1, 2, 4, 5, 7]
print(x)
# Out:
# [1, 2, 4, 5, 7]

# %%
x = x + 4
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-6f8bcaa613ef> in <cell line: 1>()
# ----> 1 x = x + 4
#       2 print(x)
#
# TypeError: can only concatenate list (not "int") to list

# %%
for i in range(len(x)):
  x[i] = x[i] + 4
print(x)
# Out:
# [ 9 10 12 13 15]

# %%
x = np.array([1, 2, 4, 5, 7])
print(x)
# Out:
# [1 2 4 5 7]

# %%
x = x+4
print(x)
# Out:
# [ 5  6  8  9 11]

# %% [markdown]
# 2 3 4
#
# 5 6 7

# %%
# declare an array of 2 rows, 3 columns
x = np.array([[2,3,4],[5,6,7]])

# %%
print(x)
# Out:
# [[2 3 4]
#  [5 6 7]]

# %%
x = np.array([1, 2, 4, 5, 7])

# %%
print(x[3])
# Out:
# 5

# %%
print(x[-2])
# Out:
# 5

# %%
x = np.array([[2,3,4],[5,6,7]])
print(x[1][1])
print(x[1,1])
# Out:
# 6
# 6

# %%
x = np.array([[[2,3,4],[5,6,7]],[[2,3,4],[5,6,7]]])
print(x)
# Out:
# [[[2 3 4]
#   [5 6 7]]
#
#  [[2 3 4]
#   [5 6 7]]]

# %% [markdown]
# x[start:end] = [x[start], x[start+1], ....., x[end-1]]

# %%
x = np.array([1, 2, 4, 5, 7])
print(x[1:4])
# Out:
# [2 4 5]

# %%
x[1:-1:2]
# Out:
# array([2, 5])

# %%
print(x[1:-1])
# Out:
# [2 4 5]

# %% [markdown]
# x[start:end:step] = x[start], x[start+step], x[start+2*step],.... x[end-1]

# %%
print(x[0:5:1])
# Out:
# [1 2 4 5 7]

# %%
print(x[1:4:2])
# Out:
# [2 5]

# %%
print(x[::1])
# Out:
# [1 2 4 5 7]

# %%
print(x[::-1])
# Out:
# [7 5 4 2 1]

# %%
print(x[::-2])
# Out:
# [7 4 1]

# %%
x = np.array([[2,3,4],[5,6,7]])
print(x)
# Out:
# [[2 3 4]
#  [5 6 7]]

# %%
print(x[0,:])
# Out:
# [2 3 4]

# %%
print(x[:,-1:])
# Out:
# [[4]
#  [7]]

# %%
print(x[:,::2])
# Out:
# [[2 4]
#  [5 7]]

# %% [markdown]
# `x[start:end]`
#
# `x[start:end:step]`
#
# `x[::]`
#
# start is not specified, 0
#
# end is not specified, len(x)
#
# step is not specified, 1

# %%
# boolean indexing

x = np.array([2, 1, -5, -4, 4, 5])

# %%
x>0
# Out:
# array([ True,  True, False, False,  True,  True])

# %%
x[x>0]
# Out:
# array([2, 1, 4, 5])

# %%
x*(x>0)
# Out:
# array([2, 1, 0, 0, 4, 5])

# %%
index = [False, False, True, True, False, False]

# %%
x[index]
# Out:
# array([-5, -4])

# %%
index = x < 0

# %%
index
# Out:
# array([False, False,  True,  True, False, False])

# %%
x[index]
# Out:
# array([-5, -4])

# %%
x[ x < 0 ]
# Out:
# array([-5, -4])

# %% [markdown]
# ## Slicing Summary
#
# `x[start:end:step] = [x[start], x[start+step], x[start+2*step], ... x[end-1]]`
#
# If `start` not specified, assumes `0`
#
# If `end` not specified, assumes `len(x)`
#
# If `step` not specified, assumes `1`
#
# **Boolean indexing**: `x[ind]` where `ind` is an array of `True` and `False` with the same size as `x`

# %%
x = np.array([4, 1, -1, 2, 4, 5])
print(x[1:4]) # [1, -1, 2]
print(x[1:]) # [1, -1, 2, 4, 5]
print(x[:4]) # []
print(x[:]) # []
print(x[2::2]) # []
print(x[:6:2]) # []
# Out:
# [ 1 -1  2]
# [ 1 -1  2  4  5]
# [ 4  1 -1  2]
# [ 4  1 -1  2  4  5]
# [-1  4]
# [ 4 -1  4]

# %% [markdown]
# # Image as NumPy array

# %%
x = np.random.rand(4, 5)
print(x)
print("shape -", x.shape)
# Out:
# [[0.76879902 0.580542   0.54589382 0.18161097 0.79713962]
#  [0.43832604 0.62795917 0.6889376  0.59726593 0.78560171]
#  [0.61686447 0.3435938  0.09222196 0.75069755 0.37505581]
#  [0.81403935 0.67097263 0.0837349  0.74173719 0.21691475]]
# shape - (4, 5)

# %%
plt.imshow(x)
plt.axis("off")
# Out:
# (-0.5, 4.5, 3.5, -0.5)

# %%
io.imshow(x, cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 4.5, 3.5, -0.5)

# %%
io.imshow(x)
#plt.axis("off")

# %%
x.shape
# Out:
# (4, 5)

# %%
#height, width = x.shape[:2]
height = x.shape[0]
width = x.shape[1]
print("Height =", height)
print("Width =", width)
# Out:
# Height = 4
# Width = 5

# %%
x = np.random.rand(4, 5, 3)
height, width, nchannels = x.shape
print("Height =", height)
print("Width =", width)
print("Number of channels =", nchannels)
# Out:
# Height = 4
# Width = 5
# Number of channels = 3

# %%
print("Red Channel")
print(x[:, :, 0])

print("Green Channel")
print(x[:, :, 1])

print("Blue Channel")
print(x[:, :, 2])
# Out:
# Red Channel
# [[0.1046221  0.94379458 0.49867368 0.4072501  0.18268625]
#  [0.19038598 0.47737239 0.78175373 0.4145341  0.20085712]
#  [0.84016143 0.6113461  0.4409473  0.98786312 0.4050546 ]
#  [0.24337732 0.08132166 0.71050084 0.6153397  0.69088394]]
# Green Channel
# [[0.72997166 0.03905735 0.43559962 0.27808749 0.75456015]
#  [0.01559555 0.03664242 0.26851198 0.9842898  0.18351119]
#  [0.40504844 0.77637855 0.13295036 0.62899644 0.39795204]
#  [0.31349516 0.93775188 0.9437913  0.35114843 0.34882959]]
# Blue Channel
# [[0.84415987 0.0046682  0.62437225 0.70548926 0.03274685]
#  [0.95902539 0.80227921 0.11563454 0.88609566 0.42563658]
#  [0.15957848 0.85952012 0.63725084 0.44547025 0.80590269]
#  [0.33983458 0.14523712 0.02351391 0.90276148 0.09785922]]

# %%
io.imshow(x)
plt.axis("off")
# Out:
# (-0.5, 4.5, 3.5, -0.5)

# %%
plt.figure(figsize=(2, 2))
x_cropped = x[:3, :3,:]
io.imshow(x_cropped)
plt.axis("off")
# Out:
# (-0.5, 2.5, 2.5, -0.5)

# %% [markdown]
# # Real Digital Image

# %%
I = io.imread("cat_1.jpg")
height, width = I.shape[:2]
print("Height =", height)
print("Width =", width)
# Out:
# Height = 2657
# Width = 1771

# %%
plt.figure(figsize=(4, 4))
io.imshow(I)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %%
print(I)
# Out:
# [[[161 163 175]
#   [162 164 176]
#   [164 166 178]
#   ...
#   [155 140 121]
#   [150 135 116]
#   [143 130 113]]
#
#  [[162 164 176]
#   [163 165 177]
#   [164 166 178]
#   ...
#   [155 140 121]
#   [150 135 116]
#   [144 131 114]]
#
#  [[165 165 177]
#   [166 166 178]
#   [167 167 179]
#   ...
#   [154 139 120]
#   [149 134 115]
#   [143 130 113]]
#
#  ...
#
#  [[ 23  22  18]
#   [ 23  22  18]
#   [ 23  22  17]
#   ...
#   [189 181 162]
#   [187 179 160]
#   [185 177 158]]
#
#  [[ 23  22  18]
#   [ 23  22  18]
#   [ 23  22  18]
#   ...
#   [189 181 162]
#   [187 179 160]
#   [185 177 158]]
#
#  [[ 22  21  19]
#   [ 22  21  17]
#   [ 22  21  17]
#   ...
#   [192 181 163]
#   [189 178 160]
#   [186 175 155]]]

# %%
x = I[0, 0]
y = I[0, -1]
print(x)
print(y)
# Out:
# [161 163 175]
# [143 130 113]

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Problem with **uint8**

# %%
x + y
# Out:
# array([48, 37, 32], dtype=uint8)

# %%
# Bad way of normalization
# I = I/255

# Good way
I = img_as_float(I)
I = img_as_float(I)

# %%
plt.figure(figsize=(3, 3))
io.imshow(I)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %% [markdown]
# ## Example 2

# %%
I = io.imread("cat_1.jpg")

# %%
I.shape
# Out:
# (2657, 1771, 3)

# %%
height, width, nchannels = I.shape
print("Height =", height)
print("Width =", width)
print("Number of channels =", nchannels)
# Out:
# Height = 2657
# Width = 1771
# Number of channels = 3

# %%
io.imshow(I)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Red channel
axes[0].imshow(I[:, :, 0], cmap="gray")
axes[0].axis("off")
axes[0].set_title("Red")

# Green channel
axes[1].imshow(I[:, :, 1], cmap="gray")
axes[1].axis("off")
axes[1].set_title("Green")

# Blue channel
axes[2].imshow(I[:, :, 2], cmap="gray")
axes[2].axis("off")
axes[2].set_title("Blue")
# Out:
# Text(0.5, 1.0, 'Blue')

# %%
# Only the left half of the image
I_cropped = I[:, :width//2, :]
io.imshow(I_cropped)
plt.axis("off")
# Out:
# (-0.5, 884.5, 2656.5, -0.5)

# %%
# Only the  bottom half of the image
I_cropped = I[height//2:, :, :]
io.imshow(I_cropped)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 1328.5, -0.5)

# %%
# flip along widht (with respect to y axis)
I_flipped = I[:, ::-1, :]
io.imshow(I_flipped)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %%
# flip along height (with respect to x axis)
I_flipped = I[::-1, :, :]
io.imshow(I_flipped)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %%
# Rotate 180 degree
I_rotated = I[::-1, ::-1, :]
io.imshow(I_rotated)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 2656.5, -0.5)

# %%
#down sampling

I_rotated = I[:, ::5, :]
io.imshow(I_rotated)
plt.axis("off")
# Out:
# (-0.5, 354.5, 2656.5, -0.5)

# %%
I_rotated = I[::5, :, :]
io.imshow(I_rotated)
plt.axis("off")
# Out:
# (-0.5, 1770.5, 531.5, -0.5)

# %%
I_rotated = I[::50, ::50, :]
io.imshow(I_rotated)
plt.axis("off")
# Out:
# (-0.5, 35.5, 53.5, -0.5)

# %% [markdown]
# # Example 3

# %%
#lagbe na

I = io.imread("BracU_Logo.png")

# %%
io.imshow(I)

# %%
I.shape
# Out:
# (275, 300, 3)

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))

# Red channel
axes[0].imshow(I[:, :, 0], cmap="gray")
axes[0].axis("off")
axes[0].set_title("Red")

# Green channel
axes[1].imshow(I[:, :, 1], cmap="gray")
axes[1].axis("off")
axes[1].set_title("Green")

# Blue channel
axes[2].imshow(I[:, :, 2], cmap="gray")
axes[2].axis("off")
axes[2].set_title("Blue")

# Alpha channel
axes[3].imshow(I[:, :, 3], cmap="gray")
axes[3].axis("off")
axes[3].set_title("Alpha")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-610c1a329dae> in <cell line: 19>()
#      17
#      18 # Alpha channel
# ---> 19 axes[3].imshow(I[:, :, 3], cmap="gray")
#      20 axes[3].axis("off")
#      21 axes[3].set_title("Alpha")
#
# IndexError: index 3 is out of bounds for axis 2 with size 3
